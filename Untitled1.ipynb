# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_csv('/home/nayara/trabalhoPy/trabalhoPy_env/consulta_cand_2016_SP.csv',header=0,encoding='ISO-8859-1', delimiter=';')

# %%
df.iloc[0:,[17,28,38,42]]
# Out:
#                       NM_CANDIDATO SG_PARTIDO DT_NASCIMENTO  DS_GENERO
# 0                  IDEVALTE UNGARI         PV    03/02/1949  MASCULINO
# 1        RAFAEL MASCHERIN MONTOURO         PR    09/02/1985  MASCULINO
# 2          GLEISON JOÃO GOMES PEGO        PTB    05/09/1979  MASCULINO
# 3           DIVA APARECIDA LORANDO        PTB    23/08/1961   FEMININO
# 4             ORLANDO COUTO JUNIOR         PV    05/07/1967  MASCULINO
# ...                            ...        ...           ...        ...
# 86774      MANOEL AUGUSTO DE SOUZA       PMDB    12/01/1968  MASCULINO
# 86775       MAURÍCIO DIMAS COMISSO        PRB    20/06/1966  MASCULINO
# 86776       AILTON GOMES DE MORAES        PPS    04/07/1964  MASCULINO
# 86777        FELIPE AGUIAR MARTINS       PSDB    14/07/1988  MASCULINO
# 86778  RENER BRUNH DA SILVA MORAIS       PSOL    13/12/1965  MASCULINO
#
# [86779 rows x 4 columns]

# %%
dados = df.loc[df['DS_GENERO'] == 'FEMININO']

# %%
dados['NM_CANDIDATO']
# Out:
# 3                    DIVA APARECIDA LORANDO
# 5            MARIA APARECIDA BARBOSA SANTOS
# 7              MARIA LUCIA DE JESUS FREITAS
# 10                          TEREZA DE PAULA
# 16                  MARIA HATUMI NIJI BUZZO
#                         ...
# 86759             CLAUDINÉIA SANTOS PEREIRA
# 86764    MIRIAM APARECIDA DA SILVA ILESANMI
# 86770      LUCIMAR APARECIDA CANDIDO CHAGAS
# 86772                  MARIA DA SILVA NEVES
# 86773      REGINALVA FERREIRA DO NASCIMENTO
# Name: NM_CANDIDATO, Length: 27736, dtype: object

# %%
dados.iloc[0:,[17,28,38,42]]
# Out:
#                              NM_CANDIDATO SG_PARTIDO DT_NASCIMENTO DS_GENERO
# 3                  DIVA APARECIDA LORANDO        PTB    23/08/1961  FEMININO
# 5          MARIA APARECIDA BARBOSA SANTOS   PATRIOTA    27/04/1971  FEMININO
# 7            MARIA LUCIA DE JESUS FREITAS       PSDB    27/05/1967  FEMININO
# 10                        TEREZA DE PAULA       PSDB    12/07/1963  FEMININO
# 16                MARIA HATUMI NIJI BUZZO       PSDB    20/10/1952  FEMININO
# ...                                   ...        ...           ...       ...
# 86759           CLAUDINÉIA SANTOS PEREIRA         PV    06/04/1974  FEMININO
# 86764  MIRIAM APARECIDA DA SILVA ILESANMI    PC do B    06/02/1961  FEMININO
# 86770    LUCIMAR APARECIDA CANDIDO CHAGAS         SD    20/02/1974  FEMININO
# 86772                MARIA DA SILVA NEVES         PR    25/07/1956  FEMININO
# 86773    REGINALVA FERREIRA DO NASCIMENTO       PSDB    15/04/1981  FEMININO
#
# [27736 rows x 4 columns]
